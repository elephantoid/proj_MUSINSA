# %%
import pymysql
import random
from faker import Faker
import datetime
db= pymysql.connect(host='localhost',user='root',password='wnstjr96',db='musinsa')
curs = db.cursor(pymysql.cursors.DictCursor)
query = "select id, price from products"
curs.execute(query)
rows = curs.fetchall()
query2 = "select seq, users_id from credit_cards"
curs.execute(query2)
rows2 = curs.fetchall()
db.close()

delivery_time_type =['10:00','11:00','14:00','17:00','18:00','23:59']
start = datetime.datetime(2020, 9, 7, 12, 0, 0)
end =datetime.datetime(2020, 11, 7, 12, 0, 0)
fake = Faker('ko_KR')

credit_seq_list=[]
for i in range(1, 1001):
    line= []
    for row2 in rows2:
        if i == row2['users_id']:
            line.append(row2['seq'])
    credit_seq_list.append(line)

orders_id_users_seq= []
orders_id= 1
for i in range(1, 200):
    for _ in range(random.randint(4,12)):
        orders_id_users_seq.append([i, orders_id])
        orders_id +=1
for i in range(201, 1001):
    for _ in range(random.randint(1,4)):
        orders_id_users_seq.append([i, orders_id])
        orders_id +=1
last_orders_id = orders_id-1
print('마지막 주문 번호: ', last_orders_id)
orders_id_list = list(range(1, orders_id))
random.shuffle(orders_id_list)
# Out:
# 마지막 주문 번호:  3500

# %%
import pymysql
import random
from faker import Faker
import datetime
Faker.seed(3);
db= pymysql.connect(host='localhost',user='root',password='root',db='musinsa')
curs = db.cursor(pymysql.cursors.DictCursor)
query = "select id, price from products"
curs.execute(query)
rows = curs.fetchall()
query2 = "select seq, users_id from credit_cards"
curs.execute(query2)
rows2 = curs.fetchall()
db.close()

import pymysql
import random
from faker import Faker
import datetime
db= pymysql.connect(host='localhost',user='root',password='root',db='mall')
curs = db.cursor(pymysql.cursors.DictCursor)
query = "select id, price from products"
curs.execute(query)
rows = curs.fetchall()
query2 = "select seq, users_id from credit_cards"
curs.execute(query2)
rows2 = curs.fetchall()
db.close()

delivery_time_type =['10:00','11:00','14:00','17:00','18:00','23:59']
start = datetime.datetime(2020, 9, 7, 12, 0, 0)
end =datetime.datetime(2020, 11, 7, 12, 0, 0)
fake = Faker('ko_KR')

credit_seq_list=[]
for i in range(1, 1001):
    line= []
    for row2 in rows2:
        if i == row2['users_id']:
            line.append(row2['seq'])
    credit_seq_list.append(line)

orders_id_users_seq= []
orders_id= 1
for i in range(1, 200):
    for _ in range(random.randint(4,12)):
        orders_id_users_seq.append([i, orders_id])
        orders_id +=1
for i in range(201, 1001):
    for _ in range(random.randint(1,4)):
        orders_id_users_seq.append([i, orders_id])
        orders_id +=1
last_orders_id = orders_id-1
#print('마지막 주문 번호: ', last_orders_id)
orders_id_list = list(range(1, orders_id))
random.shuffle(orders_id_list)

users_id =0
for i in range(0,500):
    for j in range(last_orders_id):
        if orders_id_list[i] == orders_id_users_seq[j][1]:
            users_id = orders_id_users_seq[j][0]
    order_time = fake.date_time_between_dates(datetime_start=start, datetime_end=end)
    min_total_price = random.randint(30000,150000)
    total_price=0
    while total_price < min_total_price:
        products_id = random.randint(1,271)
        products_quantity = random.randint(1,5)
        total_price +=rows[products_id-1]['price']*products_quantity
        query4 = "INSERT INTO carts(orders_id, products_id, products_quantity)"\
                +" VALUES("+str(orders_id_list[i])+","+str(products_id)+","\
                +str(products_quantity)+");";
    credit_cards_seq = random.choice(credit_seq_list[users_id-1])
    delivery_day = random.randint(1,6)
    delivery_time = random.choice(delivery_time_type)
    query3 = "INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time)"\
            +" VALUES("+str(orders_id_list[i])+", "+str(users_id)+", '"+str(order_time)+"', "\
            +str(total_price)+", "+str(credit_cards_seq)+", "+str(delivery_day)+", '"\
            +delivery_time+"');";
for i in range(500,1000):
    for j in range(last_orders_id):
        if orders_id_list[i] == orders_id_users_seq[j][1]:
            users_id = orders_id_users_seq[j][0]
    order_time = fake.date_time_between_dates(datetime_start=start, datetime_end=end)
    min_total_price = random.randint(30000,150000)
    total_price=0
    while total_price < min_total_price:
        products_id = random.randint(721,900)
        products_quantity = random.randint(1,4)
        total_price +=rows[products_id-1]['price']*products_quantity
        query4 = "INSERT INTO carts(orders_id, products_id, products_quantity)"\
                +" VALUES("+str(orders_id_list[i])+","+str(products_id)+","\
                +str(products_quantity)+");";
        print(query4)
    credit_cards_seq = random.choice(credit_seq_list[users_id-1])
    delivery_day = random.randint(1,6)
    delivery_time = random.choice(delivery_time_type)
    query3 = "INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time)"\
            +" VALUES("+str(orders_id_list[i])+", "+str(users_id)+", '"+str(order_time)+"', "\
            +str(total_price)+", "+str(credit_cards_seq)+", "+str(delivery_day)+", '"\
            +delivery_time+"');";
    print(query3)
for i in range(1000,3000):
    for j in range(last_orders_id):
        if orders_id_list[i] == orders_id_users_seq[j][1]:
            users_id = orders_id_users_seq[j][0]
    order_time = fake.date_time_between_dates(datetime_start=start, datetime_end=end)
    min_total_price = random.randint(30000,50000)
    total_price=0
    while total_price < min_total_price:
        products_id = random.randint(1,2430)
        products_quantity = random.randint(1,4)
        total_price +=rows[products_id-1]['price']*products_quantity
        query4 = "INSERT INTO carts(orders_id, products_id, products_quantity)"\
                +" VALUES("+str(orders_id_list[i])+","+str(products_id)+","\
                +str(products_quantity)+");";
        print(query4)
    credit_cards_seq = random.choice(credit_seq_list[users_id-1])
    delivery_day = random.randint(1,6)
    delivery_time = random.choice(delivery_time_type)
    query3 = "INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time)"\
            +" VALUES("+str(orders_id_list[i])+", "+str(users_id)+", '"+str(order_time)+"', "\
            +str(total_price)+", "+str(credit_cards_seq)+", "+str(delivery_day)+", '"\
            +delivery_time+"');";
    print(query3)
for i in range(3000,orders_id-1):
    for j in range(last_orders_id):
        if orders_id_list[i] == orders_id_users_seq[j][1]:
            users_id = orders_id_users_seq[j][0]
            #print("[users_id]", orders_id_users_seq[j][0])
            #print("[orders_id]", orders_id_users_seq[j][1])
    order_time = fake.date_time_between_dates(datetime_start=start, datetime_end=end)
    min_total_price = random.randint(20000,200000)
    #print("\n**",i+1," 주문번호:", orders_id_list[i],"[min_total_price]", min_total_price, "원")
    total_price=0
    while total_price < min_total_price:
        products_id = random.randint(1,2430)
        products_quantity = random.randint(1,6)
       # print("\n상품 번호:", products_id)
        #print("상품 가격:",rows[products_id-1]["price"],"원")
        #print("수량:", priducts_quantity,"개")
        #print("상품 가격 * 수량:", rows[products_id-1]["price"]*priducts_quantity,"원")
        total_price += rows[products_id-1]['price']*products_quantity
        query4 ="INSERT INTO carts(orders_id,products_id,products_quantity)"\
               +"VALUES("+str(orders_id_list[i])+","+str(products_id)+","\
               +str(products_quantity)+");";
        print(query4) 
    #print("\n[총 주문가격]",total_price,"원")
    credit_cards=seq = random.choice(credit_seq_list[users_id-1])
    delivery_day = random.randint(1,6)
    delivery_time = random.choice(delivery_time_type)
    query3="INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)"\
    +"VALUES("+str(orders_id_list[i])+","+str(users_id)+",'"+str(order_time)+"',"\
    +str(total_price)+","+str(credit_cards_seq)+","+str(delivery_day)+",'"\
    +delivery_time+"');";
    print(query3)
#print(orders_id_users_seq)
# Out:
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2275,882,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2275,795,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2275,769,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2275,852,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2275,866,1);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(2275, 485, '2020-09-29 19:00:37', 87920, 947, 2, '14:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3445,793,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3445,896,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3445,830,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3445,873,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3445,726,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(3445, 967, '2020-09-30 07:04:26', 142996, 1912, 1, '11:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(744,819,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(744,754,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(744,851,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(744,875,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(744,853,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(744,849,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(744,755,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(744, 94, '2020-09-14 05:23:51', 135120, 184, 1, '18:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(979,733,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(979,885,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(979, 126, '2020-09-28 14:30:47', 555920, 241, 2, '10:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2250,824,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2250,894,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2250,839,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2250,892,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2250,777,2);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(2250, 473, '2020-10-02 04:15:52', 150400, 923, 3, '14:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1818,807,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1818,725,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1818,819,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1818,749,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(1818, 302, '2020-10-01 00:06:53', 55580, 588, 5, '18:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(852,834,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(852,855,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(852,752,2);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(852, 109, '2020-09-25 21:51:14', 46040, 210, 3, '17:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2523,857,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2523,750,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2523,866,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2523,829,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2523,801,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(2523, 583, '2020-10-02 14:38:07', 75240, 1133, 4, '14:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1741,776,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1741,900,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(1741, 271, '2020-09-20 20:21:03', 456280, 525, 3, '10:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3342,731,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3342,731,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3342,749,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3342,781,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3342,791,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3342,864,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(3342,858,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(3342, 920, '2020-09-25 16:10:27', 187350, 1814, 3, '18:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2738,763,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2738,900,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(2738, 672, '2020-11-06 21:09:03', 456840, 1311, 2, '18:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2600,796,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2600,800,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2600,843,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2600,888,3);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(2600, 615, '2020-09-11 01:39:21', 497560, 1190, 3, '14:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1536,792,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1536,776,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1536,872,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1536,818,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1536,831,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(1536, 196, '2020-10-02 06:12:41', 117740, 373, 6, '18:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1828,827,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1828,838,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1828,860,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1828,872,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1828,888,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(1828, 307, '2020-09-23 23:27:06', 594680, 597, 1, '18:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(531,880,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(531,755,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(531, 66, '2020-09-11 20:54:33', 127520, 133, 2, '17:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1716,798,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1716,721,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1716,886,2);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(1716, 264, '2020-10-07 22:18:50', 247380, 510, 1, '14:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2850,806,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2850,749,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2850,774,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2850,826,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2850,852,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(2850,826,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(2850, 720, '2020-09-25 07:02:35', 161840, 1404, 4, '18:00');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1296,779,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1296,842,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1296,877,3);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(1296, 165, '2020-10-18 14:20:58', 83460, 318, 1, '23:59');
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,896,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,735,3);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,824,2);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,770,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,772,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,767,4);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,767,1);
# INSERT INTO carts(orders_id, products_id, products_quantity) VALUES(1568,816,4);
# INSERT INTO orders(id, users_seq, time, total_price, credit_cards_seq, delivery_day, delivery_time) VALUES(
6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2725,671,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2725,1626,6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2725,607,4);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2725,666,'2020-11-03 21:46:04',133380,1461,2,'14:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,2426,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,1848,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,10,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,590,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,1917,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,1892,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,997,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,1433,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,745,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,342,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,659,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2687,2318,2);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2687,653,'2020-10-06 12:50:30',221720,1461,1,'14:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2795,2263,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2795,201,3);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2795,697,'2020-11-01 14:57:18',254600,1461,6,'23:59');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1672,739,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1672,550,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1672,656,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1672,1677,4);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(1672,248,'2020-11-04 15:55:46',74540,1461,2,'11:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(566,777,4);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(566,70,'2020-09-11 15:07:07',199600,1461,5,'11:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1864,1367,6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1864,1829,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1864,1592,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1864,3,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1864,864,2);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(1864,321,'2020-10-01 05:53:09',73700,1461,5,'17:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(69,1265,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(69,1262,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(69,1856,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(69,1526,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(69,79,6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(69,1796,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(69,247,1);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(69,9,'2020-10-03 19:31:16',141380,1461,1,'11:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(9,1008,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(9,912,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(9,313,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(9,2029,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(9,2100,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(9,560,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(9,17,6);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(9,2,'2020-10-22 00:09:53',162020,1461,4,'14:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2613,2393,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2613,2231,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2613,467,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2613,1858,6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2613,684,1);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2613,620,'2020-10-22 09:16:51',196680,1461,4,'23:59');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3115,801,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3115,1039,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3115,2115,6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3115,1337,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3115,2072,3);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(3115,824,'2020-09-24 13:55:38',118480,1461,6,'17:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2455,2132,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2455,340,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2455,478,2);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2455,555,'2020-10-08 00:49:01',184260,1461,1,'18:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2985,99,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2985,502,6);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2985,773,'2020-10-31 00:53:13',215200,1461,2,'11:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,1107,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,291,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,1646,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,22,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,625,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,990,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,2405,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,1883,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,719,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2224,666,1);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2224,463,'2020-09-24 19:27:29',234210,1461,6,'14:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3023,263,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3023,1109,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3023,2411,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3023,2179,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3023,212,5);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(3023,790,'2020-11-01 16:53:15',159488,1461,5,'14:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3114,1525,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3114,1042,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3114,2235,5);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(3114,824,'2020-09-26 02:32:05',104400,1461,3,'10:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(923,1682,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(923,2408,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(923,1057,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(923,956,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(923,71,4);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(923,119,'2020-11-05 01:55:15',466000,1461,3,'14:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2205,1413,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2205,1804,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2205,1440,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(2205,207,1);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(2205,456,'2020-10-16 09:17:47',65400,1461,6,'10:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(988,17,4);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(988,127,'2020-09-25 08:48:24',39920,1461,1,'17:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1686,1721,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1686,2415,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1686,1496,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1686,606,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1686,1104,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1686,2058,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1686,1236,2);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(1686,254,'2020-10-18 23:38:31',185140,1461,6,'23:59');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3219,1297,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3219,910,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3219,1306,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3219,22,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3219,2143,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3219,1974,4);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(3219,1633,4);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(3219,866,'2020-09-18 18:37:45',133700,1461,3,'17:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1868,1171,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(1868,155,3);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(1868,322,'2020-10-26 11:24:18',43940,1461,6,'11:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(225,1239,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(225,2399,5);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(225,30,'2020-10-29 06:41:26',36300,1461,5,'14:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(271,2382,6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(271,1100,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(271,1279,5);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(271,522,3);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(271,1438,2);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(271,2225,5);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(271,35,'2020-10-28 16:00:43',620510,1461,6,'10:00');
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(911,950,1);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(911,1119,6);
# INSERT INTO carts(orders_id,products_id,products_quantity)VALUES(911,1432,6);
# INSERT INTO orders(id, users_seq,time, total_price, credit_cards_seq, delivery_day, delivery_time)VALUES(911,118,'2020-10-21 07:07:16',210660,1461,4,'23:59');
