# %%
import matplotlib.pyplot as plt

# %%
case_path ="C:/Users/all7j/Documents/2020-2/빅데이터_거버넌스/MAIC_vitalDB/train_data/1.csv"
file = open(case_path, "r")
y = list(map(float, file.read().split()))
x = list(range(len(y)))
plt.figure(figsize=(20,5))
plt.xlabel("Time(point)")
plt.ylabel("IBP(mmHg)")
plt.plot(x,y,'b-')#color="blue"
plt.axhline(y=25, color='r',linewidth=1)
plt.axhline(y=200, color='r',linewidth=1)

# %%
import pandas as pd
import numpy as np
import csv
case_path ="C:/Users/all7j/Documents/2020-2/빅데이터_거버넌스/MAIC_vitalDB/train_data/4.csv"
df_train = pd.read_csv(case_path, header=None);
print("df_train 길이", len(df_train))
for i in range(len(df_train)-32200):#train data에 대한 정답 20초 구간 주어졌을때 5분뒤 1분동안 이벤트(저혈압)가 발생했는가? 1 or 0
    train_x = np.array(df_train[0][i:i+2000].tolist())#0~20초까지 1999
    train_y_range = np.array(df_train[0][i+2000+30000:i+2000+30000+200].tolist())#20초(2000) 뒤 5분(30000) 뒤 2초(200)간의 데이터
    if(np.min(train_x)) < 25:
        continue
    elif(np.max(train_x)>=200):
        continue
    elif(np.min(train_y_range)<25):
        continue
    elif(np.max(train_y_range)>=200):
        continue
    else:
        #print(i, 'train_x 최소: ', np.min(train_x))
        #print(i, 'train_x 최대: ', np.max(train_x))
        print(i, 'train_y_range 평균: ', np.mean(train_y_range))
# Out:
# df_train 길이 2098940
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-609e1a9b4e84> in <module>
#       8     train_x = np.array(df_train[0][i:i+2000].tolist())#0~20초까지 1999
#       9     train_y_range = np.array(df_train[0][i+2000+30000:i+2000+30000+200].tolist())#20초(2000) 뒤 5분(30000) 뒤 2초(200)간의 데이터
# ---> 10     if(np.min(train_x)) < 25:
#      11         continue
#      12     elif(np.max(train_x)>=200):
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2790     6
#    2791     """
# -> 2792     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2793                           keepdims=keepdims, initial=initial, where=where)
#    2794
#
# ...
